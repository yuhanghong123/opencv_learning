# %%
import numpy as np 
import cv2 as cv 
import matplotlib.pyplot as plt

# %%
dog = cv.imread("dog.jpg")

# %%
plt.imshow(dog[:,:,::-1])

# %% [markdown]
# # 均值滤波

# %%
img = cv.blur(dog,(5,5))

# %%
 plt.imshow(img[:,:,::-1])

# %% [markdown]
# # 高斯滤波

# %%
doggauss = cv.imread("doggauss.jpg")

# %%
plt.imshow(doggauss[:,:,::-1])

# %%
img2 = cv.GaussianBlur(doggauss,(3,3),1)

# %%
plt.imshow(img2[:,:,::-1])

# %% [markdown]
# # 中值滤波

# %%
img3 = cv.medianBlur(dog,3)

# %%
plt.imshow(img3[:,:,::-1])

# %%
plt.imshow(dog[:,:,::-1])
