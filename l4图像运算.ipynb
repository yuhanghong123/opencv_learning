# %%
import matplotlib.pyplot as plt 
import numpy as np 
import cv2 as cv

# %%
rain = cv.imread("rain.jpg")

# %%
rain.shape
# Out:
# (400, 400, 3)

# %%
view = cv.imread("view.jpg")

# %%
view.shape
# Out:
# (400, 400, 3)

# %%
plt.imshow(rain[:,:,::-1])

# %%
plt.imshow(view[:,:,::-1])

# %%
img1 = cv.addWeighted(rain,0.7,view,0.3,0)

# %%
plt.imshow(img1[:,:,::-1])
